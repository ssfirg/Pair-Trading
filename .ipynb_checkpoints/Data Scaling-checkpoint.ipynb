# %% [markdown]
# 머신러닝 모델의 성능과 정확도를 높이기 위해 데이터 스케일링을 함
# Data Scaling = 데이터 전처리
# 모든 피처들의 데이터 분포나 범위를 동일하게 조정해줄 수 있음
#
# 1) StandardScaler()
# 모든 피처들을 평균이 0, 분산이 1인 정규분포를 갖도록 만들어줌  => 표준화
# 데이터 내에 이상치가 있을 경우, 평균과 분산에 영향을 미치기 때문에 다른 스케일링 방법을 써야함
# sklearn을 활용해서 할 경우
#   - 훈련용 데이터셋에는 fit 메서드 적용 후 transform
#   - test용 데이터셋에는 바로 transform
#
# 2) MinMaxScaler()
# 모든 피처들의 값이 0~1 사이에 놓임 => 0 ~ +1
#
# 3) MaxAbsScaler()
# 모든 피처들의 절댓값이 0~1 사이에 놓임 => -1 ~ +1
#
# 4) RobustScaler()
# StandardScaler는 평균, 분산을 사용하지만 이거는 Median(중간값), Quartile(사분위값) 사용 -> 이상치의 영향을 최소화 할 수 있음
#
# 5) normalizer()
# 앞의 4가지는 각 피처의 통계치를 이용(columns단위), 하지만 이건 각 행(Row)마다 정규화가 진행
# -> 한행의 모든 피처들 사이의 유클리드 거리가 1이 되도록 데이터값을 만듦 -> 좀 더 빠르게 학습할 수 있고 과대적합 확률을 낮출 수 있음

# %%
import sklearn
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_breast_cancer

cancer=load_breast_cancer()

# %%
cancer_df = pd.DataFrame(data=cancer.data, columns=cancer.feature_names)
cancer_df['target'] = cancer.target
cancer_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
cancer_df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, test_size=0.2, random_state=3)

dtc = DecisionTreeClassifier()

# %%
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc.score(X_test, y_test)
# Out:
# 0.8771929824561403

# %% [markdown]
# ### StandardScaler를 활용해서 스케일링을 한 후 머신러닝을 하는 경우

# %%
from sklearn.preprocessing import StandardScaler

std = StandardScaler()
std.fit(X_train)
X_train_scaled = std.transform(X_train)
X_test_scaled = std.transform(X_test)
dtc.fit(X_train_scaled, y_train)
print('모델의 정확도 :', round(dtc.score(X_test_scaled, y_test), 4))
# Out:
# 모델의 정확도 : 0.9035

# %%
X_train_scaled.shape
# Out:
# (455, 30)

# %%
plt.hist(X_train_scaled.reshape(13650,1), bins=30)
# Out:
# (array([7.000e+00, 6.000e+01, 3.660e+02, 1.801e+03, 3.719e+03, 2.805e+03,
#         1.858e+03, 1.197e+03, 7.740e+02, 4.640e+02, 2.670e+02, 1.440e+02,
#         8.700e+01, 3.900e+01, 2.300e+01, 1.500e+01, 6.000e+00, 0.000e+00,
#         3.000e+00, 3.000e+00, 2.000e+00, 2.000e+00, 1.000e+00, 2.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 2.000e+00, 0.000e+00, 1.000e+00]),
#  array([-2.69552589, -2.22782123, -1.76011658, -1.29241193, -0.82470728,
#         -0.35700262,  0.11070203,  0.57840668,  1.04611134,  1.51381599,
#          1.98152064,  2.4492253 ,  2.91692995,  3.3846346 ,  3.85233925,
#          4.32004391,  4.78774856,  5.25545321,  5.72315787,  6.19086252,
#          6.65856717,  7.12627183,  7.59397648,  8.06168113,  8.52938579,
#          8.99709044,  9.46479509,  9.93249974, 10.4002044 , 10.86790905,
#         11.3356137 ]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist(X_train.reshape(13650,1),bins=30)
# Out:
# (array([1.263e+04, 1.460e+02, 1.460e+02, 2.160e+02, 1.620e+02, 9.200e+01,
#         6.000e+01, 3.500e+01, 4.000e+01, 3.200e+01, 1.400e+01, 2.100e+01,
#         1.500e+01, 1.000e+01, 1.000e+01, 4.000e+00, 3.000e+00, 4.000e+00,
#         3.000e+00, 1.000e+00, 2.000e+00, 0.000e+00, 2.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([   0. ,  141.8,  283.6,  425.4,  567.2,  709. ,  850.8,  992.6,
#         1134.4, 1276.2, 1418. , 1559.8, 1701.6, 1843.4, 1985.2, 2127. ,
#         2268.8, 2410.6, 2552.4, 2694.2, 2836. , 2977.8, 3119.6, 3261.4,
#         3403.2, 3545. , 3686.8, 3828.6, 3970.4, 4112.2, 4254. ]),
#  <BarContainer object of 30 artists>)

# %%
from sklearn.preprocessing import MinMaxScaler

mms = MinMaxScaler()
mms.fit(X_train)
X_train_scaled = mms.transform(X_train)
X_test_scaled = mms.transform(X_test)
dtc.fit(X_train_scaled, y_train)
print('모델의 정확도 :', round(dtc.score(X_test_scaled, y_test), 4))
# Out:
# 모델의 정확도 : 0.9035

# %%
from sklearn.preprocessing import MaxAbsScaler

mas = MaxAbsScaler()
mas.fit(X_train)
X_train_scaled = mas.transform(X_train)
X_test_scaled = mas.transform(X_test)
dtc.fit(X_train_scaled, y_train)
print('모델의 정확도 :', round(dtc.score(X_test_scaled, y_test), 4))
# Out:
# 모델의 정확도 : 0.8772

# %%
from sklearn.preprocessing import RobustScaler

rbs = RobustScaler()
X_train_scaled = rbs.fit_transform(X_train)
X_test_scaled = rbs.transform(X_test)
dtc.fit(X_train_scaled, y_train)
print('모델의 정확도 :', round(dtc.score(X_test_scaled, y_test), 4))
# Out:
# 모델의 정확도 : 0.886

# %%
from sklearn.preprocessing import Normalizer

norm = Normalizer()
X_train_scaled = norm.fit_transform(X_train)
X_test_scaled = norm.transform(X_test)
dtc.fit(X_train_scaled, y_train)
print('모델의 정확도 :', round(dtc.score(X_test_scaled, y_test), 4))
# Out:
# 모델의 정확도 : 0.9211
